# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Q1**

# %%
Data = pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
Names = ["Allied Signal,Bankers Trust,General Mills,ITT Industries,J.P.Morgan & Co.,Lehman Brothers,Marriott,MCI,Merrill Lynch,\
Microsoft,Morgan Stanley,Sun Microsystems,Travelers,US Airways,Warner-Lambert"]

# %%
sns.boxplot(Data)
# Out:
# <Axes: >

# %%
Data.agg(["mean","var","std"])
# Out:
# mean     33.271333
# var     287.146612
# std      16.945401
# dtype: float64

# %% [markdown]
# ***Normal distribution, Functions of Random Variables***

# %% [markdown]
# **Q1**

# %%
from scipy import stats

# %%
1-stats.norm.cdf(50,45,8)
# Out:
# 0.26598552904870054

# %% [markdown]
# **Q2**

# %% [markdown]
# **A)**

# %%
400*(1-stats.norm.cdf(44,38,6) )          #####employees having age more than 44
# Out:
# 63.46210157258283

# %%
400*(stats.norm.cdf(44,38,6)- stats.norm.cdf(38,38,6) )   #####employees having age between 38 and 44
# Out:
# 136.53789842741716

# %% [markdown]
# **B)**

# %%
400*stats.norm.cdf(30,38,6)     #####Number of employees below 30 age
# Out:
# 36.484487890347154
